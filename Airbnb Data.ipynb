# %%
# 1. Import important libraries which we are going to use

import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

# %%
# 2. Read CSV File

df=pd.read_csv(r'C:\Akshay\Data Analytics\Projects Practice\Python EDA\NYC Airbnb\datasets.csv')
df.head(10)
# Out:
#              id                                               name    host_id  \
# 0  1.312228e+06         Rental unit in Brooklyn · ★5.0 · 1 bedroom    7130382
# 1  4.527754e+07  Rental unit in New York · ★4.67 · 2 bedrooms ·...   51501835
# 2  9.710000e+17  Rental unit in New York · ★4.17 · 1 bedroom · ...  528871354
# 3  3.857863e+06  Rental unit in New York · ★4.64 · 1 bedroom · ...   19902271
# 4  4.089661e+07  Condo in New York · ★4.91 · Studio · 1 bed · 1...   61391963
# 5  4.958498e+07  Rental unit in New York · ★5.0 · 1 bedroom · 1...   51501835
# 6  4.527754e+07  Rental unit in New York · ★4.67 · 2 bedrooms ·...   51501835
# 7  9.710000e+17  Rental unit in New York · ★4.17 · 1 bedroom · ...  528871354
# 8  3.857863e+06  Rental unit in New York · ★4.64 · 1 bedroom · ...   19902271
# 9  4.089661e+07  Condo in New York · ★4.91 · Studio · 1 bed · 1...   61391963
#
#             host_name neighbourhood_group       neighbourhood   latitude  \
# ...

# %%
# 3. Drop duplicates and null values

df.isnull().sum()
df.dropna(inplace=True)
df.info()
df.duplicated().sum()
df.drop_duplicates(inplace=True)
df.duplicated().sum()
# Out:
# <class 'pandas.DataFrame'>
# Index: 20736 entries, 0 to 20769
# Data columns (total 22 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   id                              20736 non-null  float64
#  1   name                            20736 non-null  str
#  2   host_id                         20736 non-null  int64
#  3   host_name                       20736 non-null  str
#  4   neighbourhood_group             20736 non-null  str
#  5   neighbourhood                   20736 non-null  str
#  6   latitude                        20736 non-null  float64
#  7   longitude                       20736 non-null  float64
#  8   room_type                       20736 non-null  str
#  9   price                           20736 non-null  float64
#  10  minimum_nights                  20736 non-null  float64
#  11  number_of_reviews               20736 non-null  float64
# ...

# %%
# 4. Change Data Types (Type casting)

df['id']=df['id'].astype('object')
df['host_id']=df['host_id'].astype('object')
df['name']=df['name'].astype('object')
df['host_name']=df['host_name'].astype('object')
df['neighbourhood_group']=df['neighbourhood_group'].astype('object')
df['neighbourhood']=df['neighbourhood'].astype('object')
df['room_type']=df['room_type'].astype('object')
df['last_review']=df['last_review'].astype('object')
df['license']=df['license'].astype('object')
df['rating']=df['rating'].astype('object')
df['bedrooms']=df['bedrooms'].astype('object')
df['baths']=df['baths'].astype('object')
df.dtypes
# Out:
# id                                 object
# name                               object
# host_id                            object
# host_name                          object
# neighbourhood_group                object
# neighbourhood                      object
# latitude                          float64
# longitude                         float64
# room_type                          object
# price                             float64
# minimum_nights                    float64
# number_of_reviews                 float64
# last_review                        object
# reviews_per_month                 float64
# calculated_host_listings_count    float64
# availability_365                  float64
# number_of_reviews_ltm             float64
# license                            object
# rating                             object
# bedrooms                           object
# beds                                int64
# baths                              object
# dtype: object

# %% [markdown]
# ## EDA

# %% [markdown]
# Univariate Analysis

# %%
# Identyfying Outliers in price
data= df[df['price']<1500]
sns.boxplot(x='price', data=data)
# Out:
# <Axes: xlabel='price'>

# %%
plt.figure(figsize=(10,5))
sns.histplot(data=data, x='price', bins=50)
plt.title('Price Distribution')
plt.xlabel('Price')
plt.ylabel('Frequency')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
plt.figure(figsize=(6, 3))
sns.histplot(data=df, x='availability_365')
plt.title('availability_365 Distribuition')
plt.ylabel("Frequency")
plt.show()

# %%
df.dtypes
# Out:
# id                                 object
# name                               object
# host_id                            object
# host_name                          object
# neighbourhood_group                object
# neighbourhood                      object
# latitude                          float64
# longitude                         float64
# room_type                          object
# price                             float64
# minimum_nights                    float64
# number_of_reviews                 float64
# last_review                        object
# reviews_per_month                 float64
# calculated_host_listings_count    float64
# availability_365                  float64
# number_of_reviews_ltm             float64
# license                            object
# rating                             object
# bedrooms                           object
# beds                                int64
# baths                              object
# dtype: object

# %%
# price per neighbourhood group
df.groupby(by='neighbourhood_group')['price'].mean()
# Out:
# neighbourhood_group
# Bronx            118.407798
# Brooklyn         187.196647
# Manhattan        227.482034
# Queens           126.521415
# Staten Island    118.780069
# Name: price, dtype: float64

# %%
# price per bed
df['price per bed']= df['price']/df['beds']
df.groupby(by='neighbourhood_group')['price per bed'].mean()
# Out:
# neighbourhood_group
# Bronx             85.165996
# Brooklyn         128.361667
# Manhattan        151.931643
# Queens            78.507630
# Staten Island     67.728101
# Name: price per bed, dtype: float64

# %%
sns.barplot(data=df, x='neighbourhood_group', y='price', hue='room_type')
# Out:
# <Axes: xlabel='neighbourhood_group', ylabel='price'>

# %%
# number of reviews and price relation based on locations
plt.figure(figsize=(8, 5))
plt.title("Locality and Review Dependency")
sns.scatterplot(data=data, x='number_of_reviews', y='price', hue='neighbourhood_group')
plt.show()

# %%
df.dtypes
# Out:
# id                                 object
# name                               object
# host_id                            object
# host_name                          object
# neighbourhood_group                object
# neighbourhood                      object
# latitude                          float64
# longitude                         float64
# room_type                          object
# price                             float64
# minimum_nights                    float64
# number_of_reviews                 float64
# last_review                        object
# reviews_per_month                 float64
# calculated_host_listings_count    float64
# availability_365                  float64
# number_of_reviews_ltm             float64
# license                            object
# rating                             object
# bedrooms                           object
# beds                                int64
# baths                              object
# ...

# %%
sns.pairplot(data=df,vars=['price','minimum_nights','number_of_reviews','availability_365'], hue='room_type')
#sns.pairplot(data=df, vars=['price', 'minimum_nights', 'number_of_reviews', 'availability_365'], hue='room_type')

# %%
#Geographical Distribution of AirBnb Listing
plt.figure(figsize=(10, 7))
sns.scatterplot(data=df, x='longitude', y='latitude', hue='room_type')
plt.title("Geographical Distribution of AirBnb Listing")
plt.show()

# %%
corr = df[['price', 'minimum_nights', 'number_of_reviews', 'reviews_per_month', 'availability_365', 'beds']].corr()
corr
plt.figure(figsize=(8, 6))
sns.heatmap(data=corr, annot=True)
# Out:
# <Axes: >
